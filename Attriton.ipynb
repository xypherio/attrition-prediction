# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
attrition_data = pd.read_csv('Employee_Attrition-Dataset.csv')
attrition_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
attrition_data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
n_data = attrition_data.dropna()

# %%
n_data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# ### Data Visualization

# %%
data = n_data[['Attrition', 'MaritalStatus']]
grouped_data = data.groupby(['Attrition', 'MaritalStatus']).size().reset_index(name='Counts')

fig, ax = plt.subplots(figsize=(10, 6), dpi=80)
grouped_data['Attrition'] = grouped_data['Attrition']
grouped_data['MaritalStatus'] = grouped_data['MaritalStatus']

sns.barplot(x='Attrition', y='Counts', hue='MaritalStatus', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])
ax.set_title('Attrition and MaritalStatus')
ax.set_ylabel('Numbers', size=12)
ax.set_xlabel('Employee Attrition', size=12)
plt.show()

# %%
data = n_data[['Attrition', 'JobSatisfaction']]
grouped_data = data.groupby(['Attrition', 'JobSatisfaction']).size().reset_index(name='Counts')

fig, ax = plt.subplots(figsize=(10, 6), dpi=80)
grouped_data['Attrition'] = grouped_data['Attrition']
grouped_data['JobSatisfaction'] = grouped_data['JobSatisfaction']

sns.barplot(x='Attrition', y='Counts', hue='JobSatisfaction', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])
ax.set_title('Attrition and JobSatisfaction')
ax.set_ylabel('Numbers', size=12)
ax.set_xlabel('Employee Attrition', size=12)
plt.show()
# Out:
# C:\Users\CLIET\AppData\Local\Temp\ipykernel_8028\1272881482.py:8: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Attrition', y='Counts', hue='JobSatisfaction', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])

# %%
data = n_data[['Attrition', 'Gender']]
grouped_data = data.groupby(['Attrition', 'Gender']).size().reset_index(name='Counts')

fig, ax = plt.subplots(figsize=(10, 6), dpi=80)
grouped_data['Attrition'] = grouped_data['Attrition']
grouped_data['Gender'] = grouped_data['Gender']

sns.barplot(x='Attrition', y='Counts', hue='Gender', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])
ax.set_title('Attrition and Gender')
ax.set_ylabel('Numbers', size=12)
ax.set_xlabel('Employee Attrition', size=12)
plt.show()
# Out:
# C:\Users\CLIET\AppData\Local\Temp\ipykernel_8028\2610461443.py:8: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(x='Attrition', y='Counts', hue='Gender', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])

# %%
data = n_data[['Attrition', 'OverTime']]
grouped_data = data.groupby(['Attrition', 'OverTime']).size().reset_index(name='Counts')

fig, ax = plt.subplots(figsize=(10, 6), dpi=80)
grouped_data['Attrition'] = grouped_data['Attrition']
grouped_data['OverTime'] = grouped_data['OverTime']

sns.barplot(x='Attrition', y='Counts', hue='OverTime', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])
ax.set_title('Attrition and OverTime')
ax.set_ylabel('Numbers', size=12)
ax.set_xlabel('Employee Attrition', size=12)
plt.show()
# Out:
# C:\Users\CLIET\AppData\Local\Temp\ipykernel_8028\1150665099.py:8: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(x='Attrition', y='Counts', hue='OverTime', data=grouped_data, palette=['#FF6347', '#4682B4', '#ADFF2F'])

# %%
n_data['Attrition'] =[1 if n_data == 'Yes' else 0 for n_data in n_data['Attrition']]

# %%
x = n_data.drop(columns=['Attrition'])
y = n_data['Attrition']

# %%
from category_encoders import BinaryEncoder
categorical_features = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
encoder = BinaryEncoder()
x_encoded = encoder.fit_transform(x[categorical_features])
x = x.drop(categorical_features, axis=1)
x = x.reset_index(drop=True)
x_encoded = x_encoded.reset_index(drop=True)
x = pd.concat([x, x_encoded], axis=1)

# %%
attrition_data['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x, y = smote.fit_resample(x, y)

# %%
y.value_counts()
# Out:
# Attrition
# 1    1233
# 0    1233
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= .25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz

from joblib import dump, load

dcs = DecisionTreeClassifier()
dcs.fit(x_train, y_train)
export_graphviz(dcs, out_file='tree.dot', filled=True, feature_names=x_train.columns)

with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph) 

# save model
dump(dcs, "decision_tree_model.joblib")
# Out:
# ['decision_tree_model.joblib']

# %%
from sklearn.metrics import accuracy_score, precision_score
dcs_prediction = dcs.predict(x_test)
dcs_accuracy = accuracy_score(dcs_prediction, y_test)
dcs_precision = precision_score(dcs_prediction, y_test)

print(f"Accuracy: {dcs_accuracy*100}")
print(f"Precision: {dcs_precision*100}")
# Out:
# Accuracy: 82.6580226904376
# Precision: 85.29411764705883

# %%
loaded_model = load("decision_tree_model.joblib")
loaded_prediction = loaded_model.predict(x_test)
